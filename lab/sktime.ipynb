# %%
import sktime
import pandas as pd

from sktime.datasets import load_airline
from sktime.utils.plotting import plot_series

# %%
# %cd ..
# Out:
# /Users/pedrobedmar/GoogleDrive/MASTER_BIG_DATA/tfm/code

# %%
y = load_airline()
y
# Out:
# Period
# 1949-01    112.0
# 1949-02    118.0
# 1949-03    132.0
# 1949-04    129.0
# 1949-05    121.0
#            ...
# 1960-08    606.0
# 1960-09    508.0
# 1960-10    461.0
# 1960-11    390.0
# 1960-12    432.0
# Freq: M, Name: Number of airline passengers, Length: 144, dtype: float64

# %%
y.index.dtype
# Out:
# period[M]

# %%
plot_series(y)
# Out:
# (<Figure size 1152x288 with 1 Axes>,
#  <AxesSubplot:ylabel='Number of airline passengers'>)

# %%
esios_path = "datalake/clean/esios/"
ticker = "DEMANDA_REAL"
ts = pd.read_csv(esios_path+ticker+".csv", index_col="DATE").squeeze()[[ticker]]
ts.index = pd.to_datetime(ts.index)

# %%
plot_series(ts)
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:>)

# %%
plot_series(ts.loc['2022-05-01':'2022-6-01'])
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:>)

# %%
esios_path = "datalake/clean/esios/"
ticker = "GENERACIÓN_MEDIDA_TOTAL"
ts = pd.read_csv(esios_path+ticker+".csv", index_col="DATE").squeeze()
ts.index = pd.to_datetime(ts.index)

# %%
plot_series(ts)
# Out:
# (<Figure size 1152x288 with 1 Axes>,
#  <AxesSubplot:ylabel='GENERACIÓN_MEDIDA_TOTAL'>)

# %%
esios_path = "datalake/clean/esios/"
ticker = "PRECIO_MERCADO_SPOT_DIARIO"
ts = pd.read_csv(esios_path+ticker+".csv", index_col="DATE").squeeze()
ts.index = pd.to_datetime(ts.index)

# %%
plot_series(ts)
# Out:
# KeyboardInterrupt
