# %%
# %cd ../..
# Out:
# /Users/pedrobedmar/GoogleDrive/MASTER_BIG_DATA/tfm/code

# %%
from etl.generic_provider import GenericDataProvider

import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# %%
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
gdp_provider = GenericDataProvider("datalake/clean/world_bank/", want_metadata=False, tickers="GDP")

gdp = gdp_provider.get_series("GDP", freq="Y")

# %% [markdown]
# ## CO2 EUAs price

# %% [markdown]
# ### Yearly aggregation

# %%
ax = gdp.plot()
ax.set_xlabel("Date")
ax.set_ylabel("Value")
ax.set_title("Spanish GDP (per year)")
# Out:
# Text(0.5, 1.0, 'Spanish GDP (per year)')

# %%
ax = gdp.tail(23).plot()
ax.set_xlabel("Date")
ax.set_ylabel("Value")
ax.set_title("Spanish GDP (per year)")
# Out:
# Text(0.5, 1.0, 'Spanish GDP (per year)')
