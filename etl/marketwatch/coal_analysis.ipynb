# %%
# %cd ../..
# Out:
# /Users/pedrobedmar/GoogleDrive/MASTER_BIG_DATA/tfm/code

# %%
from etl.generic_provider import GenericDataProvider

import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# %%
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
coal_daily_provider = GenericDataProvider("datalake/clean/marketwatch/", want_metadata=False, tickers="DAILY_COAL_PRICE")

coal_price_daily = coal_daily_provider.get_series("DAILY_COAL_PRICE", freq="D")
coal_price_monthly = coal_daily_provider.get_series("DAILY_COAL_PRICE", freq="D", resample_by="M", group_mode="mean")

# %% [markdown]
# ## Coal ARGUS/McCloskey price

# %% [markdown]
# ### Daily aggregation

# %%
coal_price_daily.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# ### Monthly aggregation

# %%
ax = coal_price_monthly.plot()
ax.set_xlabel("Date")
ax.set_ylabel("Value")
ax.set_title("ARGUS/McCloskey coal price (per month)")
# Out:
# Text(0.5, 1.0, 'ARGUS/McCloskey coal price (per month)')
